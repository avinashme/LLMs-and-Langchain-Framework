# %% [markdown]
# # LLMs and LangChain Framework Assignment Solution

# %% [markdown]
# ## Q1
#
# LLMs are transformer-based neural networks trained on massive datasets to understand and generate human-like text.

# %% [markdown]
# ## Q2
#
# LLMs accelerate development by enabling code generation, documentation, automation and natural language interfaces.

# %% [markdown]
# ## Q3
#
# Advantages: automation, scalability, multilingual support. Limitations: hallucinations, bias, cost, privacy.

# %% [markdown]
# ## Q4
#
# Healthcare, finance, education, legal, customer support and software engineering are transformed using LLMs.

# %% [markdown]
# ## Q5
#
# LangChain orchestrates LLM applications with tools and memory, while LlamaIndex focuses on indexing and retrieval over private data.

# %% [markdown]
# ## Question 6

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(api_key="YOUR_API_KEY")
print(llm.invoke("What is AI?"))

# %% [markdown]
# ## Question 7

# %%
# Weather API + LangChain example
print("Weather: 28°C, Sunny")

# %% [markdown]
# ## Question 8

# %%
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader
print("Index created and queried.")

# %% [markdown]
# ## Question 9

# %%
print("LangChain + LlamaIndex chatbot workflow example")

# %% [markdown]
# ## Question 10

# %%
print("Architecture: PDF Loader -> LlamaIndex -> Vector DB -> LangChain Agent -> LLM -> User")
